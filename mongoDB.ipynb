# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\user\anaconda3\lib\site-packages (4.15.5)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from pymongo) (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

MONGO_URI = os.getenv("MONGO_URI")

if not MONGO_URI:
    raise ValueError("MONGO_URI environment variable not set")

# %%
connection_string = MONGO_URI

# %%
client = MongoClient(connection_string)

# %%
db = client["Live_Sensor"]

# %%
collection = db["MongoClass"]

# %%
data = {
    "name": "Hello Ji",
    "age": "55",
    "email": "iam@gmail.com"
}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('695fd9a2c0510ca7e7f6067a'), acknowledged=True)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('695a77c47a0458d1f804c044'), 'name': 'Priyansh Porwal', 'age': 20, 'email': 'ABC@gmail.com'}
# {'_id': ObjectId('695d3b683c92313322f75982'), 'name': 'Updated user', 'age': 21, 'email': 'BBB@gmail.com'}
# {'_id': ObjectId('695fd9a2c0510ca7e7f6067a'), 'name': 'Hello Ji', 'age': '55', 'email': 'iam@gmail.com'}
